# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ring_ones = pd.read_csv('../LOTR_Code/Resources/lotr_characters.csv')
ring_ones.head(10)
# Out:
#      birth              death  gender                             hair height  \
# 0      NaN                NaN  Female                              NaN    NaN
# 1  TA 2978  February 26 ,3019    Male  Dark (book) Light brown (movie)    NaN
# 2      NaN        March ,3019    Male                              NaN    NaN
# 3   TA 280             TA 515    Male                              NaN    NaN
# 4      NaN                NaN    Male                              NaN    NaN
# 5  SA 2709            SA 2962    Male                              NaN    NaN
# 6      NaN                NaN    Male                              NaN    NaN
# 7       YT             FA 455    Male                           Golden    NaN
# 8      NaN                NaN     NaN                              NaN    NaN
# 9  SA 3219            SA 3440    Male                              NaN    NaN
#
#                      name    race    realm        spouse
# ...

# %%
ring_ones.dropna()
# Out:
#                          birth  \
# 125                    SA 3209
# 134  YT, and perhaps firstborn
# 166                         YT
# 186                    TA 2990
# 194                     FA 532
# 204                    SA 3119
# 530                         YT
# 620                    TA 2925
# 686                    YT 1362
# 692                    YT 1169
# 795                  First Age
# 802                    YT 1050
# 873              March 1 ,2931
#
#                                                  death  gender  \
# 125                                               TA 2    Male
# 134                                        Still Alive    Male
# 166                                             FA 400    Male
# 186                                              FO 63    Male
# 194  Still alive; departed to ,Aman, on ,September ...    Male
# 204                                           SA 3441     Male
# 530  Still alive, departed over the sea in the earl...    Male
# ...
