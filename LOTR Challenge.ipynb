# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ring_ones = pd.read_csv('../Lord_of_the_Rings/Resources/lotr_characters.csv')
ring_ones
# Out:
#                                   birth              death  gender  \
# 0                                   NaN                NaN  Female
# 1                               TA 2978  February 26 ,3019    Male
# 2                                   NaN        March ,3019    Male
# 3                                TA 280             TA 515    Male
# 4                                   NaN                NaN    Male
# ..                                  ...                ...     ...
# 906                      Mid ,First Age             FA 495  Female
# 907                                 NaN                NaN     NaN
# 908  YT during the ,Noontide of Valinor             FA 455    Male
# 909                             TA 2917            TA 3010    Male
# 910                     Before ,TA 1944    Late ,Third Age    Male
#
#                                 hair height                    name    race  \
# 0                                NaN    NaN                  Adanel     Men
# ...

# %%
ring_ones.dropna()
# Out:
#                          birth  \
# 125                    SA 3209
# 134  YT, and perhaps firstborn
# 166                         YT
# 186                    TA 2990
# 194                     FA 532
# 204                    SA 3119
# 530                         YT
# 620                    TA 2925
# 686                    YT 1362
# 692                    YT 1169
# 795                  First Age
# 802                    YT 1050
# 873              March 1 ,2931
#
#                                                  death  gender  \
# 125                                               TA 2    Male
# 134                                        Still Alive    Male
# 166                                             FA 400    Male
# 186                                              FO 63    Male
# 194  Still alive; departed to ,Aman, on ,September ...    Male
# 204                                           SA 3441     Male
# 530  Still alive, departed over the sea in the earl...    Male
# ...

# %%
ring_lineup = ring_ones.groupby(by="race").count()
ring_lineup
# Out:
#                   birth  death  gender  hair  height  name  realm  spouse
# race
# Ainur                24     21      24     4       6    24     10      13
# Ainur,Maiar           1      0       1     0       0     1      0       0
# Balrog                1      1       1     1       0     1      0       0
# Black Uruk            1      0       1     0       1     1      1       0
# Dragon                0      0       1     0       0     1      0       0
# Dragons               3      4       5     0       2     5      1       0
# Drúedain              1      0       1     1       1     1      0       0
# Dwarf                 1      1       1     0       0     1      0       0
# Dwarven               1      1       1     0       0     1      0       0
# Dwarves              39     37      42    10       2    42     12      17
# Eagle                 1      1       1     0       0     1      0       0
# Eagles                0      0       1     0       0     1      0       0
# ...
